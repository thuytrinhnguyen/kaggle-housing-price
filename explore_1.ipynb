# %%
import pandas as pd
import seaborn as sns
from sklearn.linear_model import LinearRegression

# %%
test = pd.read_csv('test.csv')
test.drop(columns=['Id'], inplace=True)
test
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0             20       RH         80.0    11622   Pave   NaN      Reg
# 1             20       RL         81.0    14267   Pave   NaN      IR1
# 2             60       RL         74.0    13830   Pave   NaN      IR1
# 3             60       RL         78.0     9978   Pave   NaN      IR1
# 4            120       RL         43.0     5005   Pave   NaN      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 1454         160       RM         21.0     1936   Pave   NaN      Reg
# 1455         160       RM         21.0     1894   Pave   NaN      Reg
# 1456          20       RL        160.0    20000   Pave   NaN      Reg
# 1457          85       RL         62.0    10441   Pave   NaN      Reg
# 1458          60       RL         74.0     9627   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig  ... ScreenPorch PoolArea PoolQC  Fence  \
# ...

# %%
test.dtypes
# Out:
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
# Street            object
#                   ...
# MiscVal            int64
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# Length: 79, dtype: object

# %%
test['MSSubClass'] = test['MSSubClass'].astype('category')
test['YearBuilt'] = test['YearBuilt'].astype('category')
test['YearRemodAdd'] = test['YearRemodAdd'].astype('category')
test['GarageYrBlt'] = test['GarageYrBlt'].astype('category')
test['MoSold'] = test['MoSold'].astype('category')
test['YrSold'] = test['YrSold'].astype('category')
test
# Out:
#      MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0            20       RH         80.0    11622   Pave   NaN      Reg
# 1            20       RL         81.0    14267   Pave   NaN      IR1
# 2            60       RL         74.0    13830   Pave   NaN      IR1
# 3            60       RL         78.0     9978   Pave   NaN      IR1
# 4           120       RL         43.0     5005   Pave   NaN      IR1
# ...         ...      ...          ...      ...    ...   ...      ...
# 1454        160       RM         21.0     1936   Pave   NaN      Reg
# 1455        160       RM         21.0     1894   Pave   NaN      Reg
# 1456         20       RL        160.0    20000   Pave   NaN      Reg
# 1457         85       RL         62.0    10441   Pave   NaN      Reg
# 1458         60       RL         74.0     9627   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig  ... ScreenPorch PoolArea PoolQC  Fence  \
# ...

# %%
train = pd.read_csv('train.csv')
train.drop(columns=['Id'], inplace=True)
train
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0             60       RL         65.0     8450   Pave   NaN      Reg
# 1             20       RL         80.0     9600   Pave   NaN      Reg
# 2             60       RL         68.0    11250   Pave   NaN      IR1
# 3             70       RL         60.0     9550   Pave   NaN      IR1
# 4             60       RL         84.0    14260   Pave   NaN      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 1455          60       RL         62.0     7917   Pave   NaN      Reg
# 1456          20       RL         85.0    13175   Pave   NaN      Reg
# 1457          70       RL         66.0     9042   Pave   NaN      Reg
# 1458          20       RL         68.0     9717   Pave   NaN      Reg
# 1459          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature  \
# ...

# %%
train['MSSubClass'] = train['MSSubClass'].astype('category')
train['YearBuilt'] = train['YearBuilt'].astype('category')
train['YearRemodAdd'] = train['YearRemodAdd'].astype('category')
train['GarageYrBlt'] = train['GarageYrBlt'].astype('category')
train['MoSold'] = train['MoSold'].astype('category')
train['YrSold'] = train['YrSold'].astype('category')
train
# Out:
#      MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0            60       RL         65.0     8450   Pave   NaN      Reg
# 1            20       RL         80.0     9600   Pave   NaN      Reg
# 2            60       RL         68.0    11250   Pave   NaN      IR1
# 3            70       RL         60.0     9550   Pave   NaN      IR1
# 4            60       RL         84.0    14260   Pave   NaN      IR1
# ...         ...      ...          ...      ...    ...   ...      ...
# 1455         60       RL         62.0     7917   Pave   NaN      Reg
# 1456         20       RL         85.0    13175   Pave   NaN      Reg
# 1457         70       RL         66.0     9042   Pave   NaN      Reg
# 1458         20       RL         68.0     9717   Pave   NaN      Reg
# 1459         20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature  \
# ...

# %%
train.dtypes
# Out:
# MSSubClass       category
# MSZoning         category
# LotFrontage       float64
# LotArea             int64
# Street           category
#                    ...
# MoSold           category
# YrSold           category
# SaleType         category
# SaleCondition    category
# SalePrice           int64
# Length: 80, dtype: object

# %%
train.columns
# Out:
# Index(['MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street', 'Alley',
#        'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope',
#        'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle',
#        'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle',
#        'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'MasVnrArea',
#        'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond',
#        'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating', 'HeatingQC',
#        'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual', 'TotRmsAbvGrd',
#        'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType', 'GarageYrBlt',
# ...

# %%
train.describe()
# Out:
#        LotFrontage        LotArea  OverallQual  OverallCond   MasVnrArea  \
# count  1201.000000    1460.000000  1460.000000  1460.000000  1452.000000
# mean     70.049958   10516.828082     6.099315     5.575342   103.685262
# std      24.284752    9981.264932     1.382997     1.112799   181.066207
# min      21.000000    1300.000000     1.000000     1.000000     0.000000
# 25%      59.000000    7553.500000     5.000000     5.000000     0.000000
# 50%      69.000000    9478.500000     6.000000     5.000000     0.000000
# 75%      80.000000   11601.500000     7.000000     6.000000   166.000000
# max     313.000000  215245.000000    10.000000     9.000000  1600.000000
#
#         BsmtFinSF1   BsmtFinSF2    BsmtUnfSF  TotalBsmtSF     1stFlrSF  ...  \
# count  1460.000000  1460.000000  1460.000000  1460.000000  1460.000000  ...
# mean    443.639726    46.549315   567.240411  1057.429452  1162.626712  ...
# std     456.098091   161.319273   441.866955   438.705324   386.587738  ...
# ...

# %%
train['MSSubClass'].value_counts()
# Out:
# 20     536
# 60     299
# 50     144
# 120     87
# 30      69
# 160     63
# 70      60
# 80      58
# 90      52
# 190     30
# 85      20
# 75      16
# 45      12
# 180     10
# 40       4
# Name: MSSubClass, dtype: int64

# %%
for col in train.columns.to_list():
    if train[col].dtype == 'object':
        train[col] = train[col].astype('category')

# %%
for col in test.columns.to_list():
    if test[col].dtype == 'object':
        test[col] = test[col].astype('category')

# %%
train.dtypes
# Out:
# MSSubClass       category
# MSZoning         category
# LotFrontage       float64
# LotArea             int64
# Street           category
#                    ...
# MoSold           category
# YrSold           category
# SaleType         category
# SaleCondition    category
# SalePrice           int64
# Length: 80, dtype: object

# %%
test.dtypes
# Out:
# MSSubClass       category
# MSZoning         category
# LotFrontage       float64
# LotArea             int64
# Street           category
#                    ...
# MiscVal             int64
# MoSold           category
# YrSold           category
# SaleType         category
# SaleCondition    category
# Length: 79, dtype: object

# %%
cor = train.corr()
cor
# Out:
#                LotFrontage   LotArea  OverallQual  OverallCond  MasVnrArea  \
# LotFrontage       1.000000  0.426095     0.251646    -0.059213    0.193458
# LotArea           0.426095  1.000000     0.105806    -0.005636    0.104160
# OverallQual       0.251646  0.105806     1.000000    -0.091932    0.411876
# OverallCond      -0.059213 -0.005636    -0.091932     1.000000   -0.128101
# MasVnrArea        0.193458  0.104160     0.411876    -0.128101    1.000000
# BsmtFinSF1        0.233633  0.214103     0.239666    -0.046231    0.264736
# BsmtFinSF2        0.049900  0.111170    -0.059119     0.040229   -0.072319
# BsmtUnfSF         0.132644 -0.002618     0.308159    -0.136841    0.114442
# TotalBsmtSF       0.392075  0.260833     0.537808    -0.171098    0.363936
# 1stFlrSF          0.457181  0.299475     0.476224    -0.144203    0.344501
# 2ndFlrSF          0.080177  0.050986     0.295493     0.028942    0.174561
# ...

# %%
cor_price = cor['SalePrice'].to_frame()
cor_price
# Out:
#                SalePrice
# LotFrontage     0.351799
# LotArea         0.263843
# OverallQual     0.790982
# OverallCond    -0.077856
# MasVnrArea      0.477493
# BsmtFinSF1      0.386420
# BsmtFinSF2     -0.011378
# BsmtUnfSF       0.214479
# TotalBsmtSF     0.613581
# 1stFlrSF        0.605852
# 2ndFlrSF        0.319334
# LowQualFinSF   -0.025606
# GrLivArea       0.708624
# BsmtFullBath    0.227122
# BsmtHalfBath   -0.016844
# FullBath        0.560664
# HalfBath        0.284108
# BedroomAbvGr    0.168213
# KitchenAbvGr   -0.135907
# TotRmsAbvGrd    0.533723
# Fireplaces      0.466929
# GarageCars      0.640409
# GarageArea      0.623431
# WoodDeckSF      0.324413
# OpenPorchSF     0.315856
# EnclosedPorch  -0.128578
# 3SsnPorch       0.044584
# ScreenPorch     0.111447
# PoolArea        0.092404
# MiscVal        -0.021190
# SalePrice       1.000000

# %%
cor_price.sort_values('SalePrice', ascending=False, inplace=True)

# %%
cor_price
# Out:
#                SalePrice
# SalePrice       1.000000
# OverallQual     0.790982
# GrLivArea       0.708624
# GarageCars      0.640409
# GarageArea      0.623431
# TotalBsmtSF     0.613581
# 1stFlrSF        0.605852
# FullBath        0.560664
# TotRmsAbvGrd    0.533723
# MasVnrArea      0.477493
# Fireplaces      0.466929
# BsmtFinSF1      0.386420
# LotFrontage     0.351799
# WoodDeckSF      0.324413
# 2ndFlrSF        0.319334
# OpenPorchSF     0.315856
# HalfBath        0.284108
# LotArea         0.263843
# BsmtFullBath    0.227122
# BsmtUnfSF       0.214479
# BedroomAbvGr    0.168213
# ScreenPorch     0.111447
# PoolArea        0.092404
# 3SsnPorch       0.044584
# BsmtFinSF2     -0.011378
# BsmtHalfBath   -0.016844
# MiscVal        -0.021190
# LowQualFinSF   -0.025606
# OverallCond    -0.077856
# EnclosedPorch  -0.128578
# KitchenAbvGr   -0.135907

# %%
cor_price.index
# Out:
# Index(['SalePrice', 'OverallQual', 'GrLivArea', 'GarageCars', 'GarageArea',
#        'TotalBsmtSF', '1stFlrSF', 'FullBath', 'TotRmsAbvGrd', 'MasVnrArea',
#        'Fireplaces', 'BsmtFinSF1', 'LotFrontage', 'WoodDeckSF', '2ndFlrSF',
#        'OpenPorchSF', 'HalfBath', 'LotArea', 'BsmtFullBath', 'BsmtUnfSF',
#        'BedroomAbvGr', 'ScreenPorch', 'PoolArea', '3SsnPorch', 'BsmtFinSF2',
#        'BsmtHalfBath', 'MiscVal', 'LowQualFinSF', 'OverallCond',
#        'EnclosedPorch', 'KitchenAbvGr'],
#       dtype='object')

# %%
sns.pairplot(data=train, x_vars=['OverallQual', 'GrLivArea', 'GarageCars', 'GarageArea',
       'TotalBsmtSF', '1stFlrSF'], y_vars=['SalePrice'])

# %%
sns.pairplot(data=train, x_vars=['FullBath', 'TotRmsAbvGrd', 'MasVnrArea',
       'Fireplaces', 'BsmtFinSF1', 'LotFrontage', 'WoodDeckSF'], y_vars=['SalePrice'])

# %%
sns.pairplot(data=train, x_vars=['2ndFlrSF',
       'OpenPorchSF', 'HalfBath', 'LotArea', 'BsmtFullBath', 'BsmtUnfSF',
       'BedroomAbvGr', 'ScreenPorch'], y_vars=['SalePrice'])

# %%
sns.pairplot(data=train, x_vars=[ 'PoolArea', '3SsnPorch', 'BsmtFinSF2',
       'BsmtHalfBath', 'MiscVal', 'LowQualFinSF', 'OverallCond',
       'EnclosedPorch', 'KitchenAbvGr'], y_vars=['SalePrice'])

# %%
non_na_cols = train.columns[(train.isna().sum() == 0) & (train.columns != 'SalePrice')].values

# %%
set(x_train.columns) - set(x_test.columns)
# Out:
# {'Condition2_RRAe',
#  'Condition2_RRAn',
#  'Condition2_RRNn',
#  'Exterior1st_ImStucc',
#  'Exterior1st_Stone',
#  'Exterior2nd_Other',
#  'Heating_GasA',
#  'Heating_OthW',
#  'HouseStyle_2.5Fin',
#  'RoofMatl_CompShg',
#  'RoofMatl_Membran',
#  'RoofMatl_Metal',
#  'RoofMatl_Roll',
#  'Utilities_NoSeWa',
#  'YearBuilt_1875',
#  'YearBuilt_1882',
#  'YearBuilt_1885',
#  'YearBuilt_1892',
#  'YearBuilt_1893',
#  'YearBuilt_1898',
#  'YearBuilt_1904',
#  'YearBuilt_1906',
#  'YearBuilt_1908',
#  'YearBuilt_1911',
#  'YearBuilt_1913'}

# %%
x_train = train[non_na_cols]
x_train = pd.get_dummies(data=x_train, drop_first=True)
y_train = train['SalePrice']

# %%
lm = LinearRegression()
lm.fit(x_train, y_train)
lm.score(x_train, y_train)
# Out:
# 0.9311911030181492

# %%
x_test = test[non_na_cols]
x_test = pd.get_dummies(data=x_test, drop_first=True)

# %%
for col in x_test.columns.to_list():
    if x_test[col].isna().sum() > 0:
        x_test[col].fillna(x_test[col].mean(), inplace=True)

# %%
x_train.shape
# Out:
# (1460, 383)

# %%
lm.predict(x_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-181-e6a7796722e0> in <module>
# ----> 1 lm.predict(x_test)
#
# ~\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_base.py in predict(self, X)
#     234             Returns predicted values.
#     235         """
# --> 236         return self._decision_function(X)
#     237
#     238     _preprocess_data = staticmethod(_preprocess_data)
#
# ~\miniconda3\envs\ml\lib\site-packages\sklearn\linear_model\_base.py in _decision_function(self, X)
#     217
#     218         X = check_array(X, accept_sparse=['csr', 'csc', 'coo'])
# --> 219         return safe_sparse_dot(X, self.coef_.T,
#     220                                dense_output=True) + self.intercept_
#     221
#
# ~\miniconda3\envs\ml\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
# ...
